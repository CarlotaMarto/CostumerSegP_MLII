# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
#
# <h1 style="margin-bottom:0;"><b> Machine Learning II - Project 1</b></h1>
# <br>
#
# <h3><b> Group _ </b></h3>
#
# <b>Carlota Marto</b> — 20241729</li>\
# <b>Francisca Teixeira</b> — 20241702</li>
# </ul>
# <h4>LCD  —  Teachers: Ivo Bernardo  — 2025/26 </h4>
#
# </div>

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:15px; border-radius:10px;">
#
# **Table of Contents**

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b>1. Introduction </b></h3>

# %% [markdown]
#  <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px">
# <b> 1.1. Project Context and Goal

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.EDA </b></h3>

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.1 Imports and Data Loading </b></h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("customer_info.csv")
print(f"Dataset shape: {df.shape[0]:,} rows and {df.shape[1]} columns")
# Out:
# Dataset shape: 33,038 rows and 25 columns

# %%
display(df.head())
display(df.tail())
# Out:
#    customer_id          customer_name customer_gender   customer_birthdate  \
# 0            3  Bsc. Crystal Kitchens          female  02/12/1970 01:36 PM
# 1            4     Bsc. Glenda Bauman          female  11/13/1975 06:58 PM
# 2            5  Msc. Antonio Campbell            male  09/10/1971 10:07 AM
# 3            7           John Kelling            male  10/23/1982 11:20 AM
# 4            8        Arthur Dematteo            male  08/04/1969 10:22 PM
#
#    kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0        1.0         1.0                1.0                      3.0
# 1        1.0         0.0                0.0                      2.0
# 2        0.0         0.0                NaN                      2.0
# 3        0.0         0.0                2.0                      1.0
# 4        0.0         0.0                3.0                      1.0
#
#    lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# 0                   11731.0                      4553.0  ...
# 1                   13694.0                       963.0  ...
# 2                   12407.0                         0.0  ...
# 3                    7493.0                      1105.0  ...
# 4                    9187.0                     10841.0  ...
#
#    lifetime_spend_fish  lifetime_spend_hygiene  lifetime_spend_videogames  \
# 0                213.0                   552.0                      256.0
# 1                 15.0                  1880.0                      333.0
# 2                273.0                   507.0                      101.0
# 3               1083.0                   485.0                     1656.0
# 4               1015.0                   297.0                     1258.0
#
#    lifetime_spend_petfood  lifetime_total_distinct_products  \
# 0                   384.0                             189.0
# 1                   665.0                             130.0
# 2                   222.0                              81.0
# 3                   184.0                              92.0
# 4                   441.0                               6.0
#
#    percentage_of_products_bought_promotion  year_first_transaction  \
# 0                                 0.631599                  2020.0
# 1                                 0.149890                  2013.0
# 2                                 0.069126                  2005.0
# 3                                 0.253609                  2021.0
# 4                                 0.186569                  2021.0
#
#    loyalty_card_number   latitude  longitude
# 0                  1.0  38.794428  -9.215739
# 1                  1.0  38.751711  -9.179611
# 2                  NaN  38.780678  -9.160656
# 3                  1.0  38.739548  -9.148679
# 4                  1.0  38.733071  -9.188188
#
# [5 rows x 25 columns]
#        customer_id   customer_name customer_gender   customer_birthdate  \
# 33033        39996   Joshua Howard            male  05/16/1973 02:04 PM
# 33034        39997   Anthony Hines            male  05/10/1955 01:19 AM
# 33035        39998  Edna Hasselman          female  05/15/1945 11:09 PM
# 33036        39999   George Kramer            male  05/25/1951 09:02 PM
# 33037        40000   Sammie Wright          female  07/09/1990 10:27 AM
#
#        kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 33033        0.0         0.0                2.0                      1.0
# 33034        1.0         0.0                1.0                      1.0
# 33035        1.0         1.0                0.0                      4.0
# 33036        1.0         1.0                1.0                      6.0
# 33037        0.0         1.0                1.0                      1.0
#
#        lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# 33033                     475.0                     13488.0  ...
# 33034                    8430.0                     14408.0  ...
# 33035                    8029.0                      1480.0  ...
# 33036                    8364.0                      3114.0  ...
# 33037                    4774.0                      2127.0  ...
#
#        lifetime_spend_fish  lifetime_spend_hygiene  lifetime_spend_videogames  \
# 33033               1154.0                    62.0                     1598.0
# 33034                602.0                   220.0                     2105.0
# 33035                  NaN                  1719.0                       89.0
# 33036                113.0                   410.0                        NaN
# 33037                729.0                  1331.0                      323.0
#
#        lifetime_spend_petfood  lifetime_total_distinct_products  \
# 33033                   366.0                             162.0
# 33034                   227.0                              97.0
# 33035                   258.0                             206.0
# 33036                   225.0                             385.0
# 33037                   239.0                             102.0
#
#        percentage_of_products_bought_promotion  year_first_transaction  \
# 33033                                 0.261352                  2014.0
# 33034                                 0.143479                  2014.0
# 33035                                 0.181917                  2012.0
# 33036                                 0.807259                  2017.0
# 33037                                 0.252563                  2017.0
#
#        loyalty_card_number   latitude  longitude
# 33033                  NaN  38.742306  -9.163971
# 33034                  NaN  38.748505  -9.193445
# 33035                  NaN  38.776003  -9.137943
# 33036                  NaN  38.736034  -9.145235
# 33037                  NaN  38.758936  -9.145988
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33038 entries, 0 to 33037
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customer_id                              33038 non-null  int64
#  1   customer_name                            33038 non-null  object
#  2   customer_gender                          33038 non-null  object
#  3   customer_birthdate                       32873 non-null  object
#  4   kids_home                                32708 non-null  float64
#  5   teens_home                               32708 non-null  float64
#  6   number_complaints                        32377 non-null  float64
#  7   distinct_stores_visited                  32708 non-null  float64
#  8   lifetime_spend_groceries                 33038 non-null  float64
#  9   lifetime_spend_electronics               32377 non-null  float64
#  10  typical_hour                             32377 non-null  float64
#  11  lifetime_spend_vegetables                32377 non-null  float64
#  12  lifetime_spend_nonalcohol_drinks         33038 non-null  float64
#  13  lifetime_spend_alcohol_drinks            32708 non-null  float64
#  14  lifetime_spend_meat                      32377 non-null  float64
#  15  lifetime_spend_fish                      32047 non-null  float64
#  16  lifetime_spend_hygiene                   32708 non-null  float64
#  17  lifetime_spend_videogames                32377 non-null  float64
#  18  lifetime_spend_petfood                   32377 non-null  float64
#  19  lifetime_total_distinct_products         33038 non-null  float64
#  20  percentage_of_products_bought_promotion  32708 non-null  float64
#  21  year_first_transaction                   33038 non-null  float64
#  22  loyalty_card_number                      19932 non-null  float64
#  23  latitude                                 33038 non-null  float64
#  24  longitude                                33038 non-null  float64
# dtypes: float64(21), int64(1), object(3)
# memory usage: 6.3+ MB

# %%
print("\nDATA TYPES:")
print(df.dtypes)
# Out:
# DATA TYPES:
# customer_id                                  int64
# customer_name                               object
# customer_gender                             object
# customer_birthdate                          object
# kids_home                                  float64
# teens_home                                 float64
# number_complaints                          float64
# distinct_stores_visited                    float64
# lifetime_spend_groceries                   float64
# lifetime_spend_electronics                 float64
# typical_hour                               float64
# lifetime_spend_vegetables                  float64
# lifetime_spend_nonalcohol_drinks           float64
# lifetime_spend_alcohol_drinks              float64
# lifetime_spend_meat                        float64
# lifetime_spend_fish                        float64
# lifetime_spend_hygiene                     float64
# lifetime_spend_videogames                  float64
# lifetime_spend_petfood                     float64
# lifetime_total_distinct_products           float64
# percentage_of_products_bought_promotion    float64
# year_first_transaction                     float64
# loyalty_card_number                        float64
# latitude                                   float64
# longitude                                  float64
# dtype: object

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.2 Duplicate Rows Analysis </b></h3>

# %%
duplicate_rows = df[df.duplicated()]
display(duplicate_rows.head())
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, customer_gender, customer_birthdate, kids_home, teens_home, number_complaints, distinct_stores_visited, lifetime_spend_groceries, lifetime_spend_electronics, typical_hour, lifetime_spend_vegetables, lifetime_spend_nonalcohol_drinks, lifetime_spend_alcohol_drinks, lifetime_spend_meat, lifetime_spend_fish, lifetime_spend_hygiene, lifetime_spend_videogames, lifetime_spend_petfood, lifetime_total_distinct_products, percentage_of_products_bought_promotion, year_first_transaction, loyalty_card_number, latitude, longitude]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.3 Missing Values Analysis </b></h3>

# %%
missing_count = df.isnull().sum()
missing_percent = (missing_count / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': missing_count.index,
    'Data_Type': df.dtypes.values,
    'Missing_Count': missing_count.values,
    'Missing_Percent': missing_percent.values
})

missing_df['Missing_Percent'] = missing_df['Missing_Percent'].round(2)
missing_df = missing_df.sort_values('Missing_Count', ascending=False)
display(missing_df)
# Out:
#                                      Column Data_Type  Missing_Count  \
# 22                      loyalty_card_number   float64          13106
# 15                      lifetime_spend_fish   float64            991
# 9                lifetime_spend_electronics   float64            661
# 17                lifetime_spend_videogames   float64            661
# 14                      lifetime_spend_meat   float64            661
# 11                lifetime_spend_vegetables   float64            661
# 10                             typical_hour   float64            661
# 18                   lifetime_spend_petfood   float64            661
# 6                         number_complaints   float64            661
# 7                   distinct_stores_visited   float64            330
# 20  percentage_of_products_bought_promotion   float64            330
# 5                                teens_home   float64            330
# 13            lifetime_spend_alcohol_drinks   float64            330
# 4                                 kids_home   float64            330
# 16                   lifetime_spend_hygiene   float64            330
# 3                        customer_birthdate    object            165
# 21                   year_first_transaction   float64              0
# 23                                 latitude   float64              0
# 0                               customer_id     int64              0
# 12         lifetime_spend_nonalcohol_drinks   float64              0
# 19         lifetime_total_distinct_products   float64              0
# 1                             customer_name    object              0
# 8                  lifetime_spend_groceries   float64              0
# 2                           customer_gender    object              0
# 24                                longitude   float64              0
#
#     Missing_Percent
# 22            39.67
# 15             3.00
# 9              2.00
# 17             2.00
# 14             2.00
# 11             2.00
# 10             2.00
# 18             2.00
# 6              2.00
# 7              1.00
# 20             1.00
# 5              1.00
# 13             1.00
# 4              1.00
# 16             1.00
# 3              0.50
# 21             0.00
# 23             0.00
# 0              0.00
# 12             0.00
# 19             0.00
# 1              0.00
# 8              0.00
# 2              0.00
# 24             0.00

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Missing_Percent', y='Column', data=missing_df)
plt.title("Missing Values Percentage by Column")
plt.xlabel("Percentage")
plt.ylabel("Column")
plt.show()

# %%
high_missing = missing_df[missing_df['Missing_Percent'] > 30]
display(high_missing)
# Out:
#                  Column Data_Type  Missing_Count  Missing_Percent
# 22  loyalty_card_number   float64          13106            39.67

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.4 Define Numerical and Categorical Columns</b></h3>

# %%
# Identify numerical and categorical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# Display columns nicely
print(f"Numerical columns ({len(numerical_cols)}):")
display(pd.DataFrame(numerical_cols, columns=['Numerical Columns']))

print(f"Categorical columns ({len(categorical_cols)}):")
display(pd.DataFrame(categorical_cols, columns=['Categorical Columns']))
# Out:
# Numerical columns (22):
#                           Numerical Columns
# 0                               customer_id
# 1                                 kids_home
# 2                                teens_home
# 3                         number_complaints
# 4                   distinct_stores_visited
# 5                  lifetime_spend_groceries
# 6                lifetime_spend_electronics
# 7                              typical_hour
# 8                 lifetime_spend_vegetables
# 9          lifetime_spend_nonalcohol_drinks
# 10            lifetime_spend_alcohol_drinks
# 11                      lifetime_spend_meat
# 12                      lifetime_spend_fish
# 13                   lifetime_spend_hygiene
# 14                lifetime_spend_videogames
# 15                   lifetime_spend_petfood
# 16         lifetime_total_distinct_products
# 17  percentage_of_products_bought_promotion
# 18                   year_first_transaction
# 19                      loyalty_card_number
# 20                                 latitude
# 21                                longitude
# Categorical columns (3):
#   Categorical Columns
# 0       customer_name
# 1     customer_gender
# 2  customer_birthdate

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 2.5 Statistical Summary</b></h3>

# %%
print("STATISTICAL SUMMARY FOR NUMERICAL COLUMNS:")
df[numerical_cols].describe().T
# Out:
# STATISTICAL SUMMARY FOR NUMERICAL COLUMNS:
#                                            count          mean           std  \
# customer_id                              33038.0  19974.265785  11538.538632
# kids_home                                32708.0      1.116118      1.150186
# teens_home                               32708.0      0.898893      0.962924
# number_complaints                        32377.0      0.930846      0.894658
# distinct_stores_visited                  32708.0      3.167941      1.674114
# lifetime_spend_groceries                 33038.0  16306.227798  11985.903518
# lifetime_spend_electronics               32377.0   2763.080088   3453.191495
# typical_hour                             32377.0     12.659388      4.854708
# lifetime_spend_vegetables                32377.0    727.223801    654.633087
# lifetime_spend_nonalcohol_drinks         33038.0    464.352776    275.767976
# lifetime_spend_alcohol_drinks            32708.0    622.144185    517.744320
# lifetime_spend_meat                      32377.0    723.721716    483.022782
# lifetime_spend_fish                      32047.0    608.781228    497.068874
# lifetime_spend_hygiene                   32708.0    820.346460    608.317320
# lifetime_spend_videogames                32377.0    373.900917    460.782042
# lifetime_spend_petfood                   32377.0    336.217099    160.234980
# lifetime_total_distinct_products         33038.0    148.914644    105.922907
# percentage_of_products_bought_promotion  32708.0      0.318866      0.283638
# year_first_transaction                   33038.0   2015.311853      5.032196
# loyalty_card_number                      19932.0      1.000000      0.000000
# latitude                                 33038.0     38.749694      0.022498
# longitude                                33038.0     -9.154549      0.028581
#
#                                                  min          25%  \
# customer_id                                 3.000000  9985.250000
# kids_home                                   0.000000     0.000000
# teens_home                                  0.000000     0.000000
# number_complaints                           0.000000     0.000000
# distinct_stores_visited                     1.000000     2.000000
# lifetime_spend_groceries                    0.000000  8647.000000
# lifetime_spend_electronics                  0.000000   579.000000
# typical_hour                                6.000000     8.000000
# lifetime_spend_vegetables                   0.000000   224.000000
# lifetime_spend_nonalcohol_drinks            0.000000   241.000000
# lifetime_spend_alcohol_drinks               0.000000   201.000000
# lifetime_spend_meat                         0.000000   343.000000
# lifetime_spend_fish                         0.000000   171.000000
# lifetime_spend_hygiene                      0.000000   362.000000
# lifetime_spend_videogames                   0.000000   125.000000
# lifetime_spend_petfood                      0.000000   225.000000
# lifetime_total_distinct_products            0.000000    67.000000
# percentage_of_products_bought_promotion    -1.274940     0.122359
# year_first_transaction                   1993.000000  2012.000000
# loyalty_card_number                         1.000000     1.000000
# latitude                                   38.687987    38.734079
# longitude                                  -9.232989    -9.173732
#
#                                                   50%           75%  \
# customer_id                              19951.500000  29964.750000
# kids_home                                    1.000000      1.000000
# teens_home                                   1.000000      1.000000
# number_complaints                            1.000000      1.000000
# distinct_stores_visited                      3.000000      4.000000
# lifetime_spend_groceries                 13002.500000  20807.000000
# lifetime_spend_electronics                1470.000000   3745.000000
# typical_hour                                12.000000     16.000000
# lifetime_spend_vegetables                  471.000000   1074.000000
# lifetime_spend_nonalcohol_drinks           421.000000    640.000000
# lifetime_spend_alcohol_drinks              483.000000    891.250000
# lifetime_spend_meat                        729.000000   1010.000000
# lifetime_spend_fish                        511.000000    923.000000
# lifetime_spend_hygiene                     686.000000   1120.000000
# lifetime_spend_videogames                  223.000000    374.000000
# lifetime_spend_petfood                     327.000000    435.000000
# lifetime_total_distinct_products           123.000000    210.000000
# percentage_of_products_bought_promotion      0.239449      0.469390
# year_first_transaction                    2015.000000   2019.000000
# loyalty_card_number                          1.000000      1.000000
# latitude                                    38.748286     38.765779
# longitude                                   -9.156689     -9.139608
#
#                                                    max
# customer_id                               40000.000000
# kids_home                                     8.000000
# teens_home                                    6.000000
# number_complaints                             7.000000
# distinct_stores_visited                      10.000000
# lifetime_spend_groceries                 104670.000000
# lifetime_spend_electronics                35299.000000
# typical_hour                                 23.000000
# lifetime_spend_vegetables                  3337.000000
# lifetime_spend_nonalcohol_drinks           2180.000000
# lifetime_spend_alcohol_drinks              3704.000000
# lifetime_spend_meat                        3052.000000
# lifetime_spend_fish                        3172.000000
# lifetime_spend_hygiene                     3482.000000
# lifetime_spend_videogames                  3936.000000
# lifetime_spend_petfood                     1224.000000
# lifetime_total_distinct_products            600.000000
# percentage_of_products_bought_promotion       1.000000
# year_first_transaction                     2029.000000
# loyalty_card_number                           1.000000
# latitude                                     38.823693
# longitude                                    -9.035697

# %%
for col in categorical_cols:
    print(f"\nColumn: {col}")
    print(f"Unique values: {df[col].nunique()}")
    display(df[col].value_counts().head(10))
# Out:
# Column: customer_name
# Unique values: 32543
# customer_name
# Susan Smith        5
# John Rodriguez     4
# David Smith        4
# John Brown         4
# James Moore        4
# Donna Anderson     4
# James Davis        4
# Michael Wilson     4
# Robert Johnson     4
# Msc. John Smith    4
# Name: count, dtype: int64
# Column: customer_gender
# Unique values: 2
# customer_gender
# female    16577
# male      16461
# Name: count, dtype: int64
# Column: customer_birthdate
# Unique values: 32852
# customer_birthdate
# 03/03/1985 07:32 AM    2
# 02/17/1967 07:11 AM    2
# 07/15/1942 10:57 PM    2
# 04/08/1979 04:26 AM    2
# 01/08/1948 05:46 AM    2
# 10/04/1974 12:14 AM    2
# 08/21/1941 11:10 AM    2
# 06/21/1987 03:10 PM    2
# 06/09/1945 12:25 AM    2
# 05/19/1973 08:31 AM    2
# Name: count, dtype: int64

# %%
if numerical_cols:
    n_cols = len(numerical_cols)
    n_rows = (n_cols + 2) // 3

    fig, axes = plt.subplots(n_rows, 3, figsize=(15, n_rows * 4))
    axes = axes.flatten()

    for i, col in enumerate(numerical_cols):
        data = df[col].dropna()

        axes[i].hist(data, bins=30, edgecolor='black', alpha=0.6)

        mean_val = data.mean()
        median_val = data.median()

        axes[i].axvline(mean_val, linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
        axes[i].axvline(median_val, linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')

        axes[i].set_title(f'Distribution of {col}')
        axes[i].legend()
        axes[i].grid(alpha=0.3)

    # Hide unused plots safely
    for j in range(len(numerical_cols), len(axes)):
        axes[j].set_visible(False)

    plt.tight_layout()
    plt.show()

# %%
if categorical_cols:
    for col in categorical_cols:
        plt.figure(figsize=(10, 5))
        df[col].value_counts().head(10).plot(kind='bar')
        plt.title(f'Top 10 values in {col}')
        plt.xticks(rotation=45)
        plt.grid(axis='y', alpha=0.3)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b>2.6 Outlier Detection</b></h3>

# %%
print("OUTLIER DETECTION USING IQR METHOD:\n")

outlier_summary = []

for col in numerical_cols:
    data = df[col].dropna()
    
    if len(data) > 0:
        Q1 = data.quantile(0.25)
        Q3 = data.quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = data[(data < lower_bound) | (data > upper_bound)]

        outlier_count = len(outliers)
        outlier_percent = (outlier_count / len(data)) * 100

        outlier_summary.append([col, outlier_count, round(outlier_percent, 2)])

# Create summary table
outlier_df = pd.DataFrame(outlier_summary, columns=['Column', 'Outlier_Count', 'Outlier_Percent'])
display(outlier_df.sort_values(by='Outlier_Percent', ascending=False))
# Out:
# OUTLIER DETECTION USING IQR METHOD:
#                                      Column  Outlier_Count  Outlier_Percent
# 14                lifetime_spend_videogames           3831            11.83
# 1                                 kids_home           2579             7.88
# 6                lifetime_spend_electronics           2087             6.45
# 2                                teens_home           2098             6.41
# 5                  lifetime_spend_groceries           1836             5.56
# 3                         number_complaints           1368             4.23
# 17  percentage_of_products_bought_promotion           1359             4.15
# 21                                longitude           1152             3.49
# 13                   lifetime_spend_hygiene           1034             3.16
# 10            lifetime_spend_alcohol_drinks            785             2.40
# 16         lifetime_total_distinct_products            515             1.56
# 15                   lifetime_spend_petfood            389             1.20
# 11                      lifetime_spend_meat            384             1.19
# 9          lifetime_spend_nonalcohol_drinks            310             0.94
# 8                 lifetime_spend_vegetables            290             0.90
# 12                      lifetime_spend_fish            266             0.83
# 4                   distinct_stores_visited            186             0.57
# 18                   year_first_transaction            100             0.30
# 20                                 latitude             76             0.23
# 7                              typical_hour              0             0.00
# 19                      loyalty_card_number              0             0.00
# 0                               customer_id              0             0.00

# %%
if numerical_cols:
    n_cols = len(numerical_cols)
    n_rows = (n_cols + 2) // 3

    fig, axes = plt.subplots(n_rows, 3, figsize=(15, n_rows * 4))
    axes = axes.flatten()

    for i, col in enumerate(numerical_cols):
        data = df[col].dropna()

        axes[i].boxplot(data, patch_artist=True)
        axes[i].set_title(f'Boxplot of {col}')
        axes[i].grid(alpha=0.3)

    # Hide unused plots
    for j in range(len(numerical_cols), len(axes)):
        axes[j].set_visible(False)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b>2.7 Correlation Matrix</b></h3>

# %%
if len(numerical_cols) >= 2:

    correlation_matrix = df[numerical_cols].corr()

    plt.figure(figsize=(12, 10))

    sns.heatmap(
        correlation_matrix,
        annot=True,
        cmap='coolwarm',
        fmt='.2f',
        linewidths=0.5,
        square=True,
        cbar_kws={'shrink': 0.8}
    )

    plt.title('Correlation Matrix for Numerical Features', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)

    plt.tight_layout()
    plt.show()

# %%
corr_pairs = correlation_matrix.abs().unstack()
corr_pairs = corr_pairs[corr_pairs < 1]  # remove self-correlation
high_corr = corr_pairs[corr_pairs > 0.8].sort_values(ascending=False)

print("Highly correlated feature pairs (>|0.8|):")
display(high_corr.head(10))
# Out:
# Highly correlated feature pairs (>|0.8|):
# Series([], dtype: float64)

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 3.DATA CLEANING</b></h3>

# %%
df_clean = df.copy()

print("Initial shape:", df_clean.shape)
# Out:
# Initial shape: (33038, 25)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33038 entries, 0 to 33037
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customer_id                              33038 non-null  int64
#  1   customer_name                            33038 non-null  object
#  2   customer_gender                          33038 non-null  object
#  3   customer_birthdate                       32873 non-null  object
#  4   kids_home                                32708 non-null  float64
#  5   teens_home                               32708 non-null  float64
#  6   number_complaints                        32377 non-null  float64
#  7   distinct_stores_visited                  32708 non-null  float64
#  8   lifetime_spend_groceries                 33038 non-null  float64
#  9   lifetime_spend_electronics               32377 non-null  float64
#  10  typical_hour                             32377 non-null  float64
#  11  lifetime_spend_vegetables                32377 non-null  float64
#  12  lifetime_spend_nonalcohol_drinks         33038 non-null  float64
#  13  lifetime_spend_alcohol_drinks            32708 non-null  float64
#  14  lifetime_spend_meat                      32377 non-null  float64
#  15  lifetime_spend_fish                      32047 non-null  float64
#  16  lifetime_spend_hygiene                   32708 non-null  float64
#  17  lifetime_spend_videogames                32377 non-null  float64
#  18  lifetime_spend_petfood                   32377 non-null  float64
#  19  lifetime_total_distinct_products         33038 non-null  float64
#  20  percentage_of_products_bought_promotion  32708 non-null  float64
#  21  year_first_transaction                   33038 non-null  float64
#  22  loyalty_card_number                      19932 non-null  float64
#  23  latitude                                 33038 non-null  float64
#  24  longitude                                33038 non-null  float64
# dtypes: float64(21), int64(1), object(3)
# memory usage: 6.3+ MB

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b>3.1 Detecting Invalid Future Years in Dataset</b></h3>

# %%
current_year = pd.Timestamp.now().year
print("Current year:", current_year)
# Out:
# Current year: 2026

# %%
# Check invalid values BEFORE fixing
invalid_years = df_clean[df_clean['year_first_transaction'] > current_year]
print("\nInvalid future years found:")
display(invalid_years['year_first_transaction'].unique())
# Out:
# Invalid future years found:
# array([], dtype=float64)

# %%
# Apply correction
df_clean['year_first_transaction'] = df_clean['year_first_transaction'].clip(upper=current_year)

# %%
# Validate AFTER fixing
print("\nMax year after correction:", df_clean['year_first_transaction'].max())
# Out:
# Max year after correction: 2026.0

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b>3.2 Fix Negative Percentages</b></h3>

# %%
negative_values = df_clean[df_clean['percentage_of_products_bought_promotion'] < 0]
print("Negative values found:")
display(negative_values['percentage_of_products_bought_promotion'].head())
# Out:
# Negative values found:
# 8    -0.131176
# 26   -0.025524
# 28   -0.184820
# 65   -0.217805
# 71   -0.022180
# Name: percentage_of_products_bought_promotion, dtype: float64

# %%
df_clean['percentage_of_products_bought_promotion'] = df_clean[
    'percentage_of_products_bought_promotion'
].clip(lower=0)

# %%
print("\nMinimum value after correction:")
print(df_clean['percentage_of_products_bought_promotion'].min())
# Out:
# Minimum value after correction:
# 0.0

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 3.3 Fix Columns Data Types</b></h3>

# %%
df_clean['customer_birthdate'] = pd.to_datetime(
    df_clean['customer_birthdate'], errors='coerce'
)

# %%
int_columns = [
    'kids_home', 'teens_home', 'number_complaints',
    'distinct_stores_visited', 'typical_hour',
    'lifetime_total_distinct_products', 'year_first_transaction'
]

for col in int_columns:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

# %%
df_clean['loyalty_card_number'] = df_clean['loyalty_card_number'].astype(str)
df_clean['loyalty_card_number'] = df_clean['loyalty_card_number'].replace('nan', 'No Card')

# %%
print("Updated data types:")
display(df_clean.dtypes)
# Out:
# Updated data types:
# customer_id                                         int64
# customer_name                                      object
# customer_gender                                    object
# customer_birthdate                         datetime64[ns]
# kids_home                                         float64
# teens_home                                        float64
# number_complaints                                 float64
# distinct_stores_visited                           float64
# lifetime_spend_groceries                          float64
# lifetime_spend_electronics                        float64
# typical_hour                                      float64
# lifetime_spend_vegetables                         float64
# lifetime_spend_nonalcohol_drinks                  float64
# lifetime_spend_alcohol_drinks                     float64
# lifetime_spend_meat                               float64
# lifetime_spend_fish                               float64
# lifetime_spend_hygiene                            float64
# lifetime_spend_videogames                         float64
# lifetime_spend_petfood                            float64
# lifetime_total_distinct_products                  float64
# percentage_of_products_bought_promotion           float64
# year_first_transaction                            float64
# loyalty_card_number                                object
# latitude                                          float64
# longitude                                         float64
# dtype: object

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 3.4 Missing Value Imputation</h3>

# %%
print("Missing values BEFORE imputation:")
display(df_clean.isna().sum())
# Out:
# Missing values BEFORE imputation:
# customer_id                                  0
# customer_name                                0
# customer_gender                              0
# customer_birthdate                         165
# kids_home                                  330
# teens_home                                 330
# number_complaints                          661
# distinct_stores_visited                    330
# lifetime_spend_groceries                     0
# lifetime_spend_electronics                 661
# typical_hour                               661
# lifetime_spend_vegetables                  661
# lifetime_spend_nonalcohol_drinks             0
# lifetime_spend_alcohol_drinks              330
# lifetime_spend_meat                        661
# lifetime_spend_fish                        991
# lifetime_spend_hygiene                     330
# lifetime_spend_videogames                  661
# lifetime_spend_petfood                     661
# lifetime_total_distinct_products             0
# percentage_of_products_bought_promotion    330
# year_first_transaction                       0
# loyalty_card_number                          0
# latitude                                     0
# longitude                                    0
# dtype: int64

# %%
df_clean.dropna(subset=['customer_birthdate'], inplace=True)

# %%
zero_cols = ['kids_home', 'teens_home', 'number_complaints']

for col in zero_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna(0)

# %%
median_cols = [
    'lifetime_spend_electronics', 'lifetime_spend_vegetables',
    'lifetime_spend_meat', 'lifetime_spend_fish',
    'lifetime_spend_videogames', 'lifetime_spend_petfood',
    'lifetime_spend_alcohol_drinks', 'lifetime_spend_hygiene',
    'typical_hour', 'percentage_of_products_bought_promotion',
    'distinct_stores_visited'
]

for col in median_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
df_clean['loyalty_card_number'] = df_clean['loyalty_card_number'].fillna('No Card')

# %%
print("\nMissing values AFTER imputation:")
display(df_clean.isna().sum())
# Out:
# Missing values AFTER imputation:
# customer_id                                0
# customer_name                              0
# customer_gender                            0
# customer_birthdate                         0
# kids_home                                  0
# teens_home                                 0
# number_complaints                          0
# distinct_stores_visited                    0
# lifetime_spend_groceries                   0
# lifetime_spend_electronics                 0
# typical_hour                               0
# lifetime_spend_vegetables                  0
# lifetime_spend_nonalcohol_drinks           0
# lifetime_spend_alcohol_drinks              0
# lifetime_spend_meat                        0
# lifetime_spend_fish                        0
# lifetime_spend_hygiene                     0
# lifetime_spend_videogames                  0
# lifetime_spend_petfood                     0
# lifetime_total_distinct_products           0
# percentage_of_products_bought_promotion    0
# year_first_transaction                     0
# loyalty_card_number                        0
# latitude                                   0
# longitude                                  0
# dtype: int64

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 3.4 Handling outliers</h3>

# %%
current_year = pd.Timestamp.now().year

df_clean['age'] = current_year - df_clean['customer_birthdate'].dt.year

# Check BEFORE fixing
print("Age before cleaning:")
print("Min age:", df_clean['age'].min())
print("Max age:", df_clean['age'].max())
# Out:
# Age before cleaning:
# Min age: 24
# Max age: 86

# %%
df_clean['age'] = df_clean['age'].clip(lower=18, upper=100)

# Validate AFTER fixing
print("\nAge after cleaning:")
print("Min age:", df_clean['age'].min())
print("Max age:", df_clean['age'].max())
# Out:
# Age after cleaning:
# Min age: 24
# Max age: 86

# %%
cols_to_cap = [
    'age',
    'lifetime_spend_groceries',
    'lifetime_spend_electronics',
    'lifetime_spend_vegetables',
    'lifetime_spend_nonalcohol_drinks',
    'lifetime_spend_alcohol_drinks',
    'lifetime_spend_meat',
    'lifetime_spend_fish',
    'lifetime_spend_hygiene',
    'lifetime_spend_videogames',
    'lifetime_spend_petfood',
    'percentage_of_products_bought_promotion'
]

for col in cols_to_cap:
    if col in df_clean.columns:

        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Apply capping
        df_clean[col] = df_clean[col].clip(lower=lower_bound, upper=upper_bound)

print("\nOutliers have been capped using the IQR method.")
# Out:
# Outliers have been capped using the IQR method.

# %% [markdown]
# <div style="background-color:#EFF5FF; padding:20px; border-radius:10px; border-left:8px solid #0047AB;">
# <h3><b> 4.Feature Engineering</h3>

# %%
df_clean['customer_title'] = df_clean['customer_name'].str.extract(
    r'(Mr|Mrs|Ms|Dr|Prof|PhD|MSc|Bsc)', expand=False
)

# Fill missing titles
df_clean['customer_title'] = df_clean['customer_title'].fillna('Unknown')

# %%
df_clean
# Out:
#        customer_id          customer_name customer_gender  customer_birthdate  \
# 0                3  Bsc. Crystal Kitchens          female 1970-02-12 13:36:00
# 1                4     Bsc. Glenda Bauman          female 1975-11-13 18:58:00
# 2                5  Msc. Antonio Campbell            male 1971-09-10 10:07:00
# 3                7           John Kelling            male 1982-10-23 11:20:00
# 4                8        Arthur Dematteo            male 1969-08-04 22:22:00
# ...            ...                    ...             ...                 ...
# 33033        39996          Joshua Howard            male 1973-05-16 14:04:00
# 33034        39997          Anthony Hines            male 1955-05-10 01:19:00
# 33035        39998         Edna Hasselman          female 1945-05-15 23:09:00
# 33036        39999          George Kramer            male 1951-05-25 21:02:00
# 33037        40000          Sammie Wright          female 1990-07-09 10:27:00
#
#        kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0            1.0         1.0                1.0                      3.0
# 1            1.0         0.0                0.0                      2.0
# 2            0.0         0.0                0.0                      2.0
# 3            0.0         0.0                2.0                      1.0
# 4            0.0         0.0                3.0                      1.0
# ...          ...         ...                ...                      ...
# 33033        0.0         0.0                2.0                      1.0
# 33034        1.0         0.0                1.0                      1.0
# 33035        1.0         1.0                0.0                      4.0
# 33036        1.0         1.0                1.0                      6.0
# 33037        0.0         1.0                1.0                      1.0
#
#        lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# 0                       11731.0                      4553.0  ...
# 1                       13694.0                       963.0  ...
# 2                       12407.0                         0.0  ...
# 3                        7493.0                      1105.0  ...
# 4                        9187.0                      8297.0  ...
# ...                         ...                         ...  ...
# 33033                     475.0                      8297.0  ...
# 33034                    8430.0                      8297.0  ...
# 33035                    8029.0                      1480.0  ...
# 33036                    8364.0                      3114.0  ...
# 33037                    4774.0                      2127.0  ...
#
#        lifetime_spend_videogames  lifetime_spend_petfood  \
# 0                          256.0                   384.0
# 1                          333.0                   665.0
# 2                          101.0                   222.0
# 3                          734.5                   184.0
# 4                          734.5                   441.0
# ...                          ...                     ...
# 33033                      734.5                   366.0
# 33034                      734.5                   227.0
# 33035                       89.0                   258.0
# 33036                      223.0                   225.0
# 33037                      323.0                   239.0
#
#        lifetime_total_distinct_products  \
# 0                                 189.0
# 1                                 130.0
# 2                                  81.0
# 3                                  92.0
# 4                                   6.0
# ...                                 ...
# 33033                             162.0
# 33034                              97.0
# 33035                             206.0
# 33036                             385.0
# 33037                             102.0
#
#        percentage_of_products_bought_promotion  year_first_transaction  \
# 0                                     0.631599                  2020.0
# 1                                     0.149890                  2013.0
# 2                                     0.069126                  2005.0
# 3                                     0.253609                  2021.0
# 4                                     0.186569                  2021.0
# ...                                        ...                     ...
# 33033                                 0.261352                  2014.0
# 33034                                 0.143479                  2014.0
# 33035                                 0.181917                  2012.0
# 33036                                 0.807259                  2017.0
# 33037                                 0.252563                  2017.0
#
#        loyalty_card_number   latitude  longitude  age  customer_title
# 0                      1.0  38.794428  -9.215739   56             Bsc
# 1                      1.0  38.751711  -9.179611   51             Bsc
# 2                  No Card  38.780678  -9.160656   55              Ms
# 3                      1.0  38.739548  -9.148679   44         Unknown
# 4                      1.0  38.733071  -9.188188   57         Unknown
# ...                    ...        ...        ...  ...             ...
# 33033              No Card  38.742306  -9.163971   53         Unknown
# 33034              No Card  38.748505  -9.193445   71         Unknown
# 33035              No Card  38.776003  -9.137943   81         Unknown
# 33036              No Card  38.736034  -9.145235   75         Unknown
# 33037              No Card  38.758936  -9.145988   36         Unknown
#
# [32873 rows x 27 columns]

# %%
df_clean = df_clean.drop(columns=['customer_name'])


print("Customer title distribution:")
display(df_clean['customer_title'].value_counts())
# Out:
# Customer title distribution:
# customer_title
# Unknown    22663
# Bsc         5126
# Ms          5032
# Dr            48
# Prof           3
# Mr             1
# Name: count, dtype: int64

# %%
# A. Create Tenure (Years as a customer)
df_clean['tenure'] = current_year - df_clean['year_first_transaction']

# B. Aggregate Spending: Total Lifetime Spend 
spend_cols = [col for col in df_clean.columns if 'lifetime_spend' in col]
df_clean['total_spend'] = df_clean[spend_cols].sum(axis=1)

# C. Household Dynamics: Total Children
df_clean['total_children'] = df_clean['kids_home'] + df_clean['teens_home']

# D. Loyalty Status: Binary Flag
df_clean['is_loyalty_member'] = df_clean['loyalty_card_number'].apply(lambda x: 0 if x == 'No Card' else 1)

# %%
df_clean = df_clean.drop(columns=['loyalty_card_number'])

# %%
df_clean
# Out:
#        customer_id customer_gender  customer_birthdate  kids_home  teens_home  \
# 0                3          female 1970-02-12 13:36:00        1.0         1.0
# 1                4          female 1975-11-13 18:58:00        1.0         0.0
# 2                5            male 1971-09-10 10:07:00        0.0         0.0
# 3                7            male 1982-10-23 11:20:00        0.0         0.0
# 4                8            male 1969-08-04 22:22:00        0.0         0.0
# ...            ...             ...                 ...        ...         ...
# 33033        39996            male 1973-05-16 14:04:00        0.0         0.0
# 33034        39997            male 1955-05-10 01:19:00        1.0         0.0
# 33035        39998          female 1945-05-15 23:09:00        1.0         1.0
# 33036        39999            male 1951-05-25 21:02:00        1.0         1.0
# 33037        40000          female 1990-07-09 10:27:00        0.0         1.0
#
#        number_complaints  distinct_stores_visited  lifetime_spend_groceries  \
# 0                    1.0                      3.0                   11731.0
# 1                    0.0                      2.0                   13694.0
# 2                    0.0                      2.0                   12407.0
# 3                    2.0                      1.0                    7493.0
# 4                    3.0                      1.0                    9187.0
# ...                  ...                      ...                       ...
# 33033                2.0                      1.0                     475.0
# 33034                1.0                      1.0                    8430.0
# 33035                0.0                      4.0                    8029.0
# 33036                1.0                      6.0                    8364.0
# 33037                1.0                      1.0                    4774.0
#
#        lifetime_spend_electronics  typical_hour  ...  \
# 0                          4553.0          12.0  ...
# 1                           963.0          12.0  ...
# 2                             0.0          11.0  ...
# 3                          1105.0          18.0  ...
# 4                          8297.0          17.0  ...
# ...                           ...           ...  ...
# 33033                      8297.0          12.0  ...
# 33034                      8297.0          21.0  ...
# 33035                      1480.0          14.0  ...
# 33036                      3114.0          11.0  ...
# 33037                      2127.0           7.0  ...
#
#        percentage_of_products_bought_promotion  year_first_transaction  \
# 0                                     0.631599                  2020.0
# 1                                     0.149890                  2013.0
# 2                                     0.069126                  2005.0
# 3                                     0.253609                  2021.0
# 4                                     0.186569                  2021.0
# ...                                        ...                     ...
# 33033                                 0.261352                  2014.0
# 33034                                 0.143479                  2014.0
# 33035                                 0.181917                  2012.0
# 33036                                 0.807259                  2017.0
# 33037                                 0.252563                  2017.0
#
#         latitude  longitude  age  customer_title  tenure  total_spend  \
# 0      38.794428  -9.215739   56             Bsc     6.0      18590.0
# 1      38.751711  -9.179611   51             Bsc    13.0      20233.0
# 2      38.780678  -9.160656   55              Ms    21.0      15549.0
# 3      38.739548  -9.148679   44         Unknown     5.0      14030.5
# 4      38.733071  -9.188188   57         Unknown     5.0      22729.5
# ...          ...        ...  ...             ...     ...          ...
# 33033  38.742306  -9.163971   53         Unknown    12.0      13865.5
# 33034  38.748505  -9.193445   71         Unknown    12.0      22038.5
# 33035  38.776003  -9.137943   81         Unknown    14.0      14604.0
# 33036  38.736034  -9.145235   75         Unknown     9.0      14738.0
# 33037  38.758936  -9.145988   36         Unknown     9.0      11553.0
#
#        total_children  is_loyalty_member
# 0                 2.0                  1
# 1                 1.0                  1
# 2                 0.0                  0
# 3                 0.0                  1
# 4                 0.0                  1
# ...               ...                ...
# 33033             0.0                  0
# 33034             1.0                  0
# 33035             2.0                  0
# 33036             2.0                  0
# 33037             1.0                  0
#
# [32873 rows x 29 columns]
